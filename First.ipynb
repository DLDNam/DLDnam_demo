# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Dọc Data từ bảng C3.csv

# %%
my_df = pd.read_csv("C3.csv")

# %% [markdown]
# #chia các bạn theo từng khối thi vào cùng bảng khác nhau

# %%
dfA00 = my_df[my_df['Exam blocks'] == 'A00']
dfA01 = my_df[my_df['Exam blocks'] == 'A01']
dfB00 = my_df[my_df['Exam blocks'] == 'B00']
dfD01 = my_df[my_df['Exam blocks'] == 'D01']

# %% [markdown]
# #Xóa cột GDCD

# %%
del my_df['Civic Education']

# %% [markdown]
# #xóa các cột không cần thiết ở các bảng

# %%
dfA00.drop(dfA00.columns[[5,6,9,10,11,12]], axis=1, inplace=True )
dfB00.drop(dfB00.columns[[5,6,7,10,11,12]], axis=1, inplace=True )
dfA01.drop(dfA01.columns[[5,8,9,10,11,12]], axis=1, inplace= True)
dfD01.drop(dfD01.columns[[7,8,9,10,11,12]], axis=1, inplace=True)
# Out:
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\2147760085.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA00.drop(dfA00.columns[[5,6,9,10,11,12]], axis=1, inplace=True )
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\2147760085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfB00.drop(dfB00.columns[[5,6,7,10,11,12]], axis=1, inplace=True )
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\2147760085.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA01.drop(dfA01.columns[[5,8,9,10,11,12]], axis=1, inplace= True)
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\2147760085.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfD01.drop(dfD01.columns[[7,8,9,10,11,12]], axis=1, inplace=True)

# %% [markdown]
# #tính tổng điểm các khối và sắp xếp tăng dần

# %%
dfA00['A00'] = dfA00['Match'] + dfA00['Chemistry'] + dfA00['Physics']
dfA00.sort_values('A00')
dfB00['B00'] = dfB00['Match'] + dfB00['Biology'] + dfB00['Chemistry']
dfB00.sort_values('B00')
dfA01['A01'] = dfA01['Match'] + dfA01['English'] + dfA01['Physics']
dfA01.sort_values('A01')
dfD01['D01'] = dfD01['Match'] + dfD01['Literature'] + dfD01['English']
dfD01.sort_values('D01')
# Out:
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\3034916602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA00['A00'] = dfA00['Match'] + dfA00['Chemistry'] + dfA00['Physics']
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\3034916602.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfB00['B00'] = dfB00['Match'] + dfB00['Biology'] + dfB00['Chemistry']
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\3034916602.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfA01['A01'] = dfA01['Match'] + dfA01['English'] + dfA01['Physics']
# C:\Users\FPT SHOP\AppData\Local\Temp\ipykernel_6980\3034916602.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfD01['D01'] = dfD01['Match'] + dfD01['Literature'] + dfD01['English']
#      NO                Name Exam blocks Class  Match  Literature  English  \
# 4    66      Pham Viet Dung         D01  12C3    8.6         7.7      8.9
# 8    82     Dam Huong Giang         D01  12C3    9.5         8.3      7.8
# 11  114  Nguyen Khanh Huyen         D01  12C3    9.5         7.8      8.7
#
#      D01
# 4   25.2
# 8   25.6
# 11  26.0

# %%
my_df['A00'] = my_df['Match'] + my_df['Chemistry'] + my_df['Physics']
my_df['B00'] = my_df['Match'] + my_df['Biology'] + my_df['Chemistry']
my_df['A01'] = my_df['Match'] + my_df['English'] + my_df['Physics']
my_df['C00'] = my_df['Literature'] + my_df['History'] + my_df['Geographic']
my_df['D00'] = my_df['Literature'] + my_df['Match'] + my_df['English']
# Out:
#      NO                   Name Exam blocks Class  Match  Literature  English  \
# 0     3              Vu Thu An         A00  12C3    9.2         7.7      7.9
# 1    30    Nguyen Tran Yen Chi         B00  12C3    9.0         8.0      7.1
# 2    36     Tran Thi Thu Trinh         B00  12C3    9.7         8.2      7.5
# 3    54        Dam Phuong Dung         A00  12C3    9.3         8.3      7.8
# 4    66         Pham Viet Dung         D01  12C3    8.6         7.7      8.9
# 5    70     Nguyen Hoang Duong         A01  12C3    9.4         7.5      7.5
# 6    71      Nguyen Ngoc Duong         A00  12C3    7.3         6.6      7.9
# 7    72         Tran Hai Duong         A01  12C3    9.1         7.4      6.9
# 8    82        Dam Huong Giang         D01  12C3    9.5         8.3      7.8
# 9    91        Trinh Minh Hieu         A00  12C3    9.8         7.7      8.1
# 10  104          Ly Viet Hoang         B00  12C3    9.2         6.7      7.2
# 11  114     Nguyen Khanh Huyen         D01  12C3    9.5         7.8      8.7
# 12  117           Ta Thi Huyen         B00  12C3    9.0         7.4      7.1
# 13  121             Do Thi Hue         B00  12C3    9.4         8.1      7.6
# 14  130          Ma Doan Hung          A00  12C3    8.8         6.9      6.7
# 15  140           Pham My Hanh         A00  12C3    9.2         8.2      8.1
# 16  159       Doan Ngan Khanh          A01  12C3    9.4         8.0      8.4
# 17  166           Le Huong Lan         A01  12C3    9.6         6.8      8.2
# 18  175      Nguyen Ngoc Linh          A01  12C3    9.3         8.1      7.2
# 19  176  Nguyen Thi Khanh Linh         B00  12C3    9.2         7.6      7.4
# 20  183   Tran Thi Phuong Linh         A00  12C3    9.4         7.4      7.9
# 21  214           Quach Thi My         B00  12C3    8.9         7.3      7.6
# 22  222           Dam Duc Manh         A00  12C3    9.0         6.7      7.0
# 23  227        Dinh Le Duc Nam         A00  12C3    9.0         7.8      6.5
# 24  231     Pham Thi Hong Ngan         B00  12C3    9.1         7.6      6.7
# 25  232      Tran Thi Kim Ngan         A00  12C3    9.8         8.0      7.9
# 26  244        Vuong Minh Ngoc         A00  12C3    8.9         8.1      7.6
# 27  247            Le Bao Nhi          B00  12C3    9.4         7.8      7.4
# 22      7.9        8.4      7.5      8.4         8.1  25.3  24.9  23.2  22.7
# 23      8.5        8.5      7.5      8.1         8.2  26.0  25.0  24.1  23.3
# 24      8.4        9.1      8.2      8.0         8.2  26.6  26.4  23.8  23.4
# 25      8.5        8.5      7.7      9.1         9.2  26.8  26.0  26.3  25.7
# 26      9.1        9.0      8.6      8.6         8.9  27.0  26.5  25.6  24.6
# 27      8.2        9.3      8.6      8.2         8.3  26.9  27.3  24.3  24.6
# 28      8.8        9.5      9.2      8.7         8.2  27.9  28.3  24.5  24.3
# 29      8.4        8.5      7.9      8.3         8.5  25.9  25.4  24.2  23.4
# 30      7.9        7.7      7.3      7.8         8.4  23.7  23.1  22.9  21.7
# 31      8.8        9.3      7.7      8.0         7.9  27.5  26.4  23.1  23.6
# 32      9.0        9.1      8.9      8.4         9.1  27.6  27.5  25.3  25.9
# 33      7.9        7.5      7.5      7.5         7.8  23.9  23.5  23.4  23.2
# 34      8.4        8.4      8.9      8.4         8.3  25.3  25.8  24.1  23.0
# 35      8.4        9.0      9.0      8.4         8.7  26.8  27.4  25.3  24.2
# 36      9.1        9.4      7.3      8.2         9.1  28.0  26.2  25.1  24.7
# 37      7.7        7.8      7.3      8.0         7.6  24.0  23.6  22.8  21.6
# 38      8.7        8.5      8.2      8.3         8.3  26.5  26.0  23.9  23.6
# 39      8.1        8.2      7.1      8.2         7.8  24.8  23.8  23.2  22.3
# 40      8.0        8.1      7.0      7.7         6.8  24.3  23.3  21.0  21.9
#
#      A01
# 0   25.4
# 1   24.8
# 2   26.0
# 3   25.9
# 4   25.4
# 5   26.2
# 6   22.9
# 7   25.1
# 8   26.1
# 9   26.7
# 10  24.7
# 11  26.8
# 12  24.7
# 13  25.3
# 14  24.5
# 15  26.1
# 16  26.5
# 17  26.2
# 18  25.8
# 19  25.3
# 20  26.3
# 21  24.8
# 22  23.9
# 23  24.0
# 24  24.2
# 25  26.2
# 26  25.6
# 27  25.0
# 28  25.5
# 29  24.4
# 30  22.9
# 31  25.2
# 32  27.1
# 33  23.0
# 34  24.0
# 35  24.4
# 36  26.0
# 37  22.1
# 38  25.0
# 39  23.2
# 40  23.4

# %% [markdown]
# #Xem Số điểm của các bạn họ Nguyễn

# %%
def Nguyen_string(title):
    if 'nguyen' in title.lower():
        return True
    else:
        return False
my_df['Name'][Nguyen_string(my_df['Name'])==True]
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30    False
# 31     True
# 32     True
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39     True
# 40    False
# Name: Name, dtype: bool
